# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    year       GNI       GDP  tax_revenue  Index_Of_Export_Market_Penetration  \
# 0  2000  1.744030  2.021089    25.022411                           16.636149
# 1  2001  3.217236  3.027378    21.400200                           17.586556
# 2  2002  2.250381  2.064875    20.656969                           18.613888
# 3  2003  6.022333  6.093705    19.052000                           19.860408
# 4  2004  6.230184  6.193653    18.829478                           20.498935
#
#    Taxes_on_goods_and_services_(%_of_revenue)          export
# 0                                   28.926505  2,09,01,797.34
# 1                                   30.150065  2,55,13,727.66
# 2                                   30.366665  2,93,36,674.75
# 3                                   30.203715  3,75,33,952.62
# 4                                   29.714834  4,56,41,786.15

# %%
# df.dropna(how='all', inplace=True)

# %%
df.tail()
# Out:
#     year       GNI       GDP  tax_revenue  Index_Of_Export_Market_Penetration  \
# 14  2014  6.270415  6.186732    15.099898                           28.246072
# 15  2015  6.819499  6.797040    14.441413                           28.122350
# 16  2016  7.009549  6.997010    12.731602                           28.619226
# 17  2017  6.097926  6.035155    12.808273                           29.526530
# 18  2018  5.769153  5.709117          NaN                           27.145362
#
#     Taxes_on_goods_and_services_(%_of_revenue)           export
# 14                                   25.557037  17,16,38,440.44
# 15                                   29.833007  18,49,43,355.34
# 16                                   31.764081  19,56,51,452.80
# 17                                   31.535759  23,07,72,619.38
# 18                                         NaN  22,19,85,418.10

# %% [markdown]
# **Remove the rows has null values**

# %%
df.drop(18, axis=0, inplace=True)

# %%
df.tail()
# Out:
#     year       GNI       GDP  tax_revenue  Index_Of_Export_Market_Penetration  \
# 13  2013  5.062503  5.134957    15.152403                           28.525995
# 14  2014  6.270415  6.186732    15.099898                           28.246072
# 15  2015  6.819499  6.797040    14.441413                           28.122350
# 16  2016  7.009549  6.997010    12.731602                           28.619226
# 17  2017  6.097926  6.035155    12.808273                           29.526530
#
#     Taxes_on_goods_and_services_(%_of_revenue)           export
# 13                                   27.300425  18,96,34,841.76
# 14                                   25.557037  17,16,38,440.44
# 15                                   29.833007  18,49,43,355.34
# 16                                   31.764081  19,56,51,452.80
# 17                                   31.535759  23,07,72,619.38

# %% [markdown]
# ### Clean export column

# %%
df['export'] = df['export'].apply(lambda x: x.replace(',',''))
df['export'].astype('float')
df.head()
# Out:
#    year       GNI       GDP  tax_revenue  Index_Of_Export_Market_Penetration  \
# 0  2000  1.744030  2.021089    25.022411                           16.636149
# 1  2001  3.217236  3.027378    21.400200                           17.586556
# 2  2002  2.250381  2.064875    20.656969                           18.613888
# 3  2003  6.022333  6.093705    19.052000                           19.860408
# 4  2004  6.230184  6.193653    18.829478                           20.498935
#
#    Taxes_on_goods_and_services_(%_of_revenue)       export
# 0                                   28.926505  20901797.34
# 1                                   30.150065  25513727.66
# 2                                   30.366665  29336674.75
# 3                                   30.203715  37533952.62
# 4                                   29.714834  45641786.15

# %% [markdown]
# **convert year column to datetime**

# %%
df['year'] = pd.to_datetime(df.year, format='%Y')

# %%
df.head()
# Out:
#         year       GNI       GDP  tax_revenue  \
# 0 2000-01-01  1.744030  2.021089    25.022411
# 1 2001-01-01  3.217236  3.027378    21.400200
# 2 2002-01-01  2.250381  2.064875    20.656969
# 3 2003-01-01  6.022333  6.093705    19.052000
# 4 2004-01-01  6.230184  6.193653    18.829478
#
#    Index_Of_Export_Market_Penetration  \
# 0                           16.636149
# 1                           17.586556
# 2                           18.613888
# 3                           19.860408
# 4                           20.498935
#
#    Taxes_on_goods_and_services_(%_of_revenue)       export
# 0                                   28.926505  20901797.34
# 1                                   30.150065  25513727.66
# 2                                   30.366665  29336674.75
# 3                                   30.203715  37533952.62
# 4                                   29.714834  45641786.15

# %% [markdown]
# **set year column as index column**

# %%
df.set_index('year', inplace=True)

# %%
df.head()
# Out:
#                  GNI       GDP  tax_revenue  \
# year
# 2000-01-01  1.744030  2.021089    25.022411
# 2001-01-01  3.217236  3.027378    21.400200
# 2002-01-01  2.250381  2.064875    20.656969
# 2003-01-01  6.022333  6.093705    19.052000
# 2004-01-01  6.230184  6.193653    18.829478
#
#             Index_Of_Export_Market_Penetration  \
# year
# 2000-01-01                           16.636149
# 2001-01-01                           17.586556
# 2002-01-01                           18.613888
# 2003-01-01                           19.860408
# 2004-01-01                           20.498935
#
#             Taxes_on_goods_and_services_(%_of_revenue)       export
# year
# 2000-01-01                                   28.926505  20901797.34
# 2001-01-01                                   30.150065  25513727.66
# 2002-01-01                                   30.366665  29336674.75
# 2003-01-01                                   30.203715  37533952.62
# 2004-01-01                                   29.714834  45641786.15

# %%
plt.rcParams["figure.figsize"] = (20,5)
df.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
### Testing For Stationarity

from statsmodels.tsa.stattools import adfuller

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['export'])
# Out:
# ADF Test Statistic : 0.19804391452815123
# p-value : 0.9721516694163255
# #Lags Used : 7
# Number of Observations Used : 10
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary
